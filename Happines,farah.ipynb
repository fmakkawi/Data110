# %% [markdown]
# <a href="https://colab.research.google.com/github/fmakkawi/Data110/blob/main/Happines%2Cfarah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/fmakkawi/Data110-32008--Sp25/refs/heads/main/dataset/happiness_2017.csv')

# %%
print(df.head())
# Out:
#        Country          Region  Rank  HappinessScore  Life Ladder  \
# 0       Norway  Western Europe     1           7.537     7.578745
# 1      Denmark  Western Europe     2           7.522     7.593702
# 2      Iceland  Western Europe     3           7.504     7.476214
# 3  Switzerland  Western Europe     4           7.494     7.473593
# 4      Finland  Western Europe     5           7.469     7.788252
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0           11.081789        0.950128                         71.086586
# 1           10.748989        0.952100                         71.662498
# 2           10.760409        0.966753                         72.755981
# 3           10.955548        0.949661                         73.173759
# 4           10.612338        0.963826                         71.696960
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# ...

# %%
print(df.tail())
# Out:
#        Country          Region  Rank  HappinessScore  Life Ladder  \
# 0       Norway  Western Europe     1           7.537     7.578745
# 1      Denmark  Western Europe     2           7.522     7.593702
# 2      Iceland  Western Europe     3           7.504     7.476214
# 3  Switzerland  Western Europe     4           7.494     7.473593
# 4      Finland  Western Europe     5           7.469     7.788252
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0           11.081789        0.950128                         71.086586
# 1           10.748989        0.952100                         71.662498
# 2           10.760409        0.966753                         72.755981
# 3           10.955548        0.949661                         73.173759
# 4           10.612338        0.963826                         71.696960
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Country                            5 non-null      object
#  1   Region                             5 non-null      object
#  2   Rank                               5 non-null      int64
#  3   HappinessScore                     5 non-null      float64
#  4   Life Ladder                        5 non-null      float64
#  5   Log GDP per capita                 5 non-null      float64
#  6   Social support                     5 non-null      float64
#  7   Healthy life expectancy at birth   5 non-null      float64
#  8   Freedom to make life choices       5 non-null      float64
#  9   Generosity                         5 non-null      float64
#  10  Perceptions of corruption          5 non-null      float64
# ...

# %%
print(df.describe())
# Out:
#            Rank  HappinessScore  Life Ladder  Log GDP per capita  \
# count  5.000000        5.000000     5.000000            5.000000
# mean   3.000000        7.505200     7.582101           10.831815
# std    1.581139        0.026129     0.128092            0.185692
# min    1.000000        7.469000     7.473593           10.612338
# 25%    2.000000        7.494000     7.476214           10.748989
# 50%    3.000000        7.504000     7.578745           10.760409
# 75%    4.000000        7.522000     7.593702           10.955548
# max    5.000000        7.537000     7.788252           11.081789
#
#        Social support  Healthy life expectancy at birth  \
# count        5.000000                          5.000000
# mean         0.956494                         72.075157
# std          0.008148                          0.860384
# min          0.949661                         71.086586
# 25%          0.950128                         71.662498
# ...

# %%
print(df.isnull().sum())
# Out:
# Country                              0
# Region                               0
# Rank                                 0
# HappinessScore                       0
# Life Ladder                          0
# Log GDP per capita                   0
# Social support                       0
# Healthy life expectancy at birth     0
# Freedom to make life choices         0
# Generosity                           0
# Perceptions of corruption            0
# Positive affect                      0
# Negative affect                      0
# Confidence in national government    0
# dtype: int64

# %%
print(df.shape)
# Out:
# (5, 14)

# %%
print(df.columns)
# Out:
# Index(['Country', 'Region', 'Rank', 'HappinessScore', 'Life Ladder',
#        'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect', 'Confidence in national government'],
#       dtype='object')

# %%
print(df.dtypes)
# Out:
# Country                               object
# Region                                object
# Rank                                   int64
# HappinessScore                       float64
# Life Ladder                          float64
# Log GDP per capita                   float64
# Social support                       float64
# Healthy life expectancy at birth     float64
# Freedom to make life choices         float64
# Generosity                           float64
# Perceptions of corruption            float64
# Positive affect                      float64
# Negative affect                      float64
# Confidence in national government    float64
# dtype: object

# %%
print(df.sample(5))
# Out:
#        Country          Region  Rank  HappinessScore  Life Ladder  \
# 1      Denmark  Western Europe     2           7.522     7.593702
# 0       Norway  Western Europe     1           7.537     7.578745
# 2      Iceland  Western Europe     3           7.504     7.476214
# 3  Switzerland  Western Europe     4           7.494     7.473593
# 4      Finland  Western Europe     5           7.469     7.788252
#
#    Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 1           10.748989        0.952100                         71.662498
# 0           11.081789        0.950128                         71.086586
# 2           10.760409        0.966753                         72.755981
# 3           10.955548        0.949661                         73.173759
# 4           10.612338        0.963826                         71.696960
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# ...

# %%
plt.plot(df['HappinessScore'], df['Life Ladder'], color='blue', linestyle='--', linewidth=2)
plt.grid(True)
plt.show()

# %%
plt.plot(df['HappinessScore'], df['Rank'], 'o-')
plt.show()

# %%
plt.scatter(df['HappinessScore'], df['Life Ladder'])
plt.show()

# %%
plt.scatter(df['Life Ladder'],df['Country'])
plt.show()

# %%
plt.plot(df['HappinessScore'], df['Freedom to make life choices'])
plt.show()

# %%
plt.plot(df['HappinessScore'],df['Generosity'])
plt.show()

# %%
plt.plot(df['HappinessScore'],df['Social support'])
plt.show()

# %%
plt.scatter(df['Generosity'], df['Healthy life expectancy at birth'], color='red')
plt.show()

# %%
plt.scatter(df['HappinessScore'], df['Log GDP per capita'], color='blue')
plt.show()
